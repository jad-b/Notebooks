# %% [markdown]
# # Student Admission

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as mtri
# Required to enable 3d projections - but not used directly!
from mpl_toolkits.mplot3d import Axes3D

# %%
ex1data = np.genfromtxt('./ex2/ex2data1.txt', delimiter=',')
X, y = ex1data[:, :2], ex1data[:, 2]

print("Loaded {} samples".format(len(X)))
# Out:
# Loaded 100 samples

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(X[:, 0], X[:, 1], y,
               cmap=plt.cm.Spectral, linewidth=0.2)
# Out:
# <img src="data:image/png;base64,...">
# /opt/conda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# Divide the training set by student admissions 
admitted, not_admitted = y==1, y==0
print("Admitted: {:d}\nNot Admitted: {:d}".format(
    len(X[admitted]), len(X[not_admitted])))
# Out:
# Admitted: 60
# Not Admitted: 40

# %%
def cost_function(theta, X, y):
    """Calculate the cost of theta on X=>y training set.
    
    We need to penalize differently depending on whether a value 
    of x should predict positive(1) or negative(0). So, in English:
    
    > If y (the true outcome) is 1, then penalize relative to how far
      from 1 our prediction fell, and vice-versa for if y is 0.
      
    In practice, we'll accomplish this by using logarithms, which
    scale towards infinity given an
    """

# %% [markdown]
# # Part Two

# %%
# Model non-linear data 
ex2data2 = np.genfromtxt('./ex2/ex2data2.txt', delimiter=',')
X2, y2 = ex2data2[:, 0], ex2data2[:, 1]
sp = plt.figure()
ax2 = sp.add_subplot(111)
ax2.scatter(X2, y2)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Questions
# > How does lambda affect under/overfitting?
#
# Underfitting occurs when your model is too simple - not enough features, or to basic of an equation - such as if you're using a linear equation to model a non-linear system.
#
# Overfitting occurs when you've over-matched your model to the training data. Too much feature engineering, such as adding in lots of polynomial terms ($x_{1}^{2}x_{2}^{3}x_{4}^{4}...$), can lead to this. Now we've forced our model to account for every variation in the training data, and we'll be fragile to any new values.
#
# > Why do we exclude the bias term from regularization?
#
# From Tom Mosher, a class Mentor:
# Penalizing $\theta_{0}$ results in a system that works badly for both the training set and for new examples, as it starts to shift the system bias toward zero.
